# %% [markdown]
# ## VARIABLE IN PYTHON

# %%
# VARIABLE
i = 42

# %%
i = i+1
print(i)
# Out:
# 43

# %%
x= "Now x referencing a string"
print(x)
# Out:
# Now x referencing a string

# %% [markdown]
# ## Valid Variable name

# %% [markdown]
# * A python identifier is a name used to
# identify a variable
# * Identifier can consist of the uppercase letters
# * it can contains lower case
# * It can contain under score _
# * Except for the first character, the
#
# 9.
